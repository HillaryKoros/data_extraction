# %% [markdown]
# ## Extracting Data from the Master Health Facility Registry (KMHFR)
#
# In this exercise, we will use the following Python libraries:
#
# - **Beautiful Soup**: For parsing HTML and XML documents.
# - **Requests**: For making HTTP requests to retrieve data from the web.
# - **JSON**: For handling JSON data structures.
# - **Pandas**: For data manipulation and analysis.
#
# ### About the Master Health Facility Registry (KMHFR)
#
# **Master Health Facility Registry (KMHFR)** is an application that contains information on all health facilities and community units in Kenya. Each health facility and community unit is identified with a unique code, along with details describing its geographical location, administrative location, ownership, type, and the services offered.
#
# ### Accessing the Data
#
# The data from KMHFR can be accessed through an API, with documentation available [here](https://mfl-api-docs.readthedocs.io/en/latest/).
#
# However, in this exercise, we will use **Beautiful Soup** to scrape the data from the KMHFR website.
#
#
# We'll be working with the following base URL:
# ```python
# base_url = "https://kmhfr.health.go.ke/public/facilities?page={}"

# %% [markdown]
# **NB: Ethical Considerations of Web Scraping**
#
# Web scraping is a powerful tool for extracting data from websites, but it comes with ethical and legal responsibilities. When scraping data from websites, it is important to:
# - **Respect the website's robots.txt file**: This file specifies which parts of the site should not be accessed by automated tools. Ignoring this can lead to legal issues or your IP being blocked.
# - **Avoid overloading the server**: Sending too many requests in a short period can strain the website's server, potentially causing disruptions in service.
# - **Use data responsibly**: Ensure that the data you scrape is used in accordance with the terms of service of the website, and respect privacy and copyright laws.
#
#
# In this exercise, web scraping is used solely for demonstration purposes. The goal is to illustrate how web scraping works and how data can be extracted and processed using Python libraries. In practice, it is recommended to use official APIs when available, as they are designed to provide access to data in a controlled and ethical manner.

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests  # Used for making HTTP requests to fetch data from websites or APIs
from bs4 import BeautifulSoup as bs  # BeautifulSoup is used for parsing HTML and XML documents, enabling easy extraction of data from web pages
import pandas as pd  # Pandas is a data manipulation and analysis library that provides data structures like DataFrames for handling and analyzing tabular data
import json  # The JSON library is used for working with JSON data, allowing you to parse JSON strings or convert Python objects to JSON
import time  # The time library is used to add delays or measure the time taken by code to execute, which can be useful for pacing requests during web scraping
import sys  # The sys library allows interaction with the Python runtime environment, including manipulating output streams and command-line arguments
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap

# %% [markdown]
# ## Data Scraping

# %% [markdown]
# ##### Get all the url pages

# %%
# Define the base URL for the KMHFR data. The placeholder `{}` will be replaced with page numbers.
base_url = "https://kmhfr.health.go.ke/public/facilities?page={}"

# Generate a list of URLs for each page from 1 to 494 by replacing the placeholder in the base URL with the page numbers.
urls = [base_url.format(page) for page in range(1, 495)]

# Print the list of generated URLs to verify the URLs created for each page.
print(urls)
# Out:
# ['https://kmhfr.health.go.ke/public/facilities?page=1', 'https://kmhfr.health.go.ke/public/facilities?page=2', 'https://kmhfr.health.go.ke/public/facilities?page=3', 'https://kmhfr.health.go.ke/public/facilities?page=4', 'https://kmhfr.health.go.ke/public/facilities?page=5', 'https://kmhfr.health.go.ke/public/facilities?page=6', 'https://kmhfr.health.go.ke/public/facilities?page=7', 'https://kmhfr.health.go.ke/public/facilities?page=8', 'https://kmhfr.health.go.ke/public/facilities?page=9', 'https://kmhfr.health.go.ke/public/facilities?page=10', 'https://kmhfr.health.go.ke/public/facilities?page=11', 'https://kmhfr.health.go.ke/public/facilities?page=12', 'https://kmhfr.health.go.ke/public/facilities?page=13', 'https://kmhfr.health.go.ke/public/facilities?page=14', 'https://kmhfr.health.go.ke/public/facilities?page=15', 'https://kmhfr.health.go.ke/public/facilities?page=16', 'https://kmhfr.health.go.ke/public/facilities?page=17', 'https://kmhfr.health.go.ke/public/facilities?page=18', 'https://kmhfr.health.go.ke/public/facilities?page=19', 'https://kmhfr.health.go.ke/public/facilities?page=20', 'https://kmhfr.health.go.ke/public/facilities?page=21', 'https://kmhfr.health.go.ke/public/facilities?page=22', 'https://kmhfr.health.go.ke/public/facilities?page=23', 'https://kmhfr.health.go.ke/public/facilities?page=24', 'https://kmhfr.health.go.ke/public/facilities?page=25', 'https://kmhfr.health.go.ke/public/facilities?page=26', 'https://kmhfr.health.go.ke/public/facilities?page=27', 'https://kmhfr.health.go.ke/public/facilities?page=28', 'https://kmhfr.health.go.ke/public/facilities?page=29', 'https://kmhfr.health.go.ke/public/facilities?page=30', 'https://kmhfr.health.go.ke/public/facilities?page=31', 'https://kmhfr.health.go.ke/public/facilities?page=32', 'https://kmhfr.health.go.ke/public/facilities?page=33', 'https://kmhfr.health.go.ke/public/facilities?page=34', 'https://kmhfr.health.go.ke/public/facilities?page=35', 'https://kmhfr.health.go.ke/public/facilities?page=36', 'https://kmhfr.health.go.ke/public/facilities?page=37', 'https://kmhfr.health.go.ke/public/facilities?page=38', 'https://kmhfr.health.go.ke/public/facilities?page=39', 'https://kmhfr.health.go.ke/public/facilities?page=40', 'https://kmhfr.health.go.ke/public/facilities?page=41', 'https://kmhfr.health.go.ke/public/facilities?page=42', 'https://kmhfr.health.go.ke/public/facilities?page=43', 'https://kmhfr.health.go.ke/public/facilities?page=44', 'https://kmhfr.health.go.ke/public/facilities?page=45', 'https://kmhfr.health.go.ke/public/facilities?page=46', 'https://kmhfr.health.go.ke/public/facilities?page=47', 'https://kmhfr.health.go.ke/public/facilities?page=48', 'https://kmhfr.health.go.ke/public/facilities?page=49', 'https://kmhfr.health.go.ke/public/facilities?page=50', 'https://kmhfr.health.go.ke/public/facilities?page=51', 'https://kmhfr.health.go.ke/public/facilities?page=52', 'https://kmhfr.health.go.ke/public/facilities?page=53', 'https://kmhfr.health.go.ke/public/facilities?page=54', 'https://kmhfr.health.go.ke/public/facilities?page=55', 'https://kmhfr.health.go.ke/public/facilities?page=56', 'https://kmhfr.health.go.ke/public/facilities?page=57', 'https://kmhfr.health.go.ke/public/facilities?page=58', 'https://kmhfr.health.go.ke/public/facilities?page=59', 'https://kmhfr.health.go.ke/public/facilities?page=60', 'https://kmhfr.health.go.ke/public/facilities?page=61', 'https://kmhfr.health.go.ke/public/facilities?page=62', 'https://kmhfr.health.go.ke/public/facilities?page=63', 'https://kmhfr.health.go.ke/public/facilities?page=64', 'https://kmhfr.health.go.ke/public/facilities?page=65', 'https://kmhfr.health.go.ke/public/facilities?page=66', 'https://kmhfr.health.go.ke/public/facilities?page=67', 'https://kmhfr.health.go.ke/public/facilities?page=68', 'https://kmhfr.health.go.ke/public/facilities?page=69', 'https://kmhfr.health.go.ke/public/facilities?page=70', 'https://kmhfr.health.go.ke/public/facilities?page=71', 'https://kmhfr.health.go.ke/publ ...

# %% [markdown]
# ##### Fetch json data for each url and combine them to a single dataframe

# %%
# Function to fetch JSON data
def fetch_json_data(url, headers):
    """
    Fetch JSON data from a given URL and headers.
    
    Parameters:
        url (str): The URL to fetch data from.
        headers (dict): The headers to use for the request.
        
    Returns:
        dict: The parsed JSON data.
    """
    # Send a GET request to the URL with the provided headers
    response = requests.get(url, headers=headers)
    
    # Parse the response content using BeautifulSoup
    soup = bs(response.text, "html.parser")
    
    # Find the script tag containing the JSON data
    script_tag = soup.find('script', id='__NEXT_DATA__')
    
    if script_tag:
        # Load and return the JSON data
        data = json.loads(script_tag.string)
        return data
    return None

# Function to convert JSON data to DataFrame
def json_to_dataframe(json_data):
    """
    Convert JSON data to a DataFrame.
    
    Parameters:
        json_data (dict): The JSON data to convert.
        
    Returns:
        DataFrame: A DataFrame containing the JSON data.
    """
    # Extract the results from the JSON data
    results = json_data.get('props', {}).get('pageProps', {}).get('data', {}).get('results', [])
    
    # Convert the results list to a DataFrame
    df = pd.DataFrame(results)
    return df

# Define the base URL for fetching data, with a placeholder for page numbers
base_url = "https://kmhfr.health.go.ke/public/facilities?page={}"

# Generate a list of URLs for each page from 1 to 494
urls = [base_url.format(page) for page in range(1, 495)]

# Define headers for HTTP requests to mimic a browser request
HEADERS = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9,fr;q=0.8",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36"
}

# Initialize an empty DataFrame to accumulate all the fetched data
all_data = pd.DataFrame()

# Loop through each URL and fetch data
for url in urls:
    data = fetch_json_data(url, HEADERS)
    if data:
        # Convert JSON data to DataFrame
        df = json_to_dataframe(data)
        # Append the DataFrame to the accumulated data
        all_data = pd.concat([all_data, df], ignore_index=True)

# %%
# Print the shape of the DataFrame (number of rows and columns)
print(f"DataFrame shape: {all_data.shape}")

# Print the number of rows in the DataFrame
print(f"Number of rows: {all_data.shape[0]}")

# Print the number of columns in the DataFrame
print(f"Number of columns: {all_data.shape[1]}")

# %% [markdown]
# DataFrame shape: (14805, 47)
# Number of rows: 14805
# Number of columns: 47

# %% [markdown]
# ### Save dataframe to local dir

# %%
# Save the combined DataFrame to a file
all_data.to_csv("data/all_facilities.csv", index=False)

# %%
all_data.columns

# %%
all_data.officialname.unique()

# %%
null_counts = all_data.isnull().sum()
print("Null values per column:")
print(null_counts)

# %% [markdown]
# ### Select Baringo County from the scraped data

# %%
county_names = df2['county_name'].value_counts()
county_names_list = county_names.index.tolist()

# Display the number of unique county names
print(f"\nNumber of unique county names: {len(county_names_list)}")
# Out:
# Number of unique county names: 47

# %%
baringo_df = df2[df2['county_name'] == 'Baringo']
baringo_df
# Out:
#           code                                 name  \
# 14     31993.0                   Ngambo Health Care
# 16     31994.0                   Mbechot Dispensary
# 18     31986.0               Elicare Medical Clinic
# 291    31598.0                Lokaimoi Medicare LTD
# 324    31366.0  Equity Afia Kabarnet Medical Center
# ...        ...                                  ...
# 14584  14867.0                Kimalel Health Centre
# 14643  15386.0                 Ol-Arabel Dispensary
# 14667  15197.0                Mogorwa Health Centre
# 14674  14979.0                 Kolowa Health Centre
# 14733  15091.0       Loruk Dispensary (Tiaty East )
#
#                               officialname registration_number  \
# 14                      Ngambo Health Care                 NaN
# 16                      Mbechot Dispensary                 NaN
# 18                  Elicare Medical Clinic              020807
# 291                  Lokaimoi Medicare LTD           COC/F/110
# 324    Equity Afia Kabarnet Medical Center              020541
# ...                                    ...                 ...
# 14584                Kimalel Health Centre                 NaN
# 14643                 Ol-Arabel Dispensary                 NaN
# 14667                Mogorwa Health Centre                 NaN
# 14674                 Kolowa Health Centre                 NaN
# 14733        Loruk Dispensary (Tiaty East)                 NaN
#
#       keph_level_name   facility_type_name facility_type_category  \
# 14            Level 2       Medical Clinic         MEDICAL CLINIC
# 16            Level 2           Dispensary             DISPENSARY
# 18            Level 2       Medical Clinic         MEDICAL CLINIC
# 291           Level 2       Medical Center         MEDICAL CENTER
# 324           Level 3       Medical Center         MEDICAL CENTER
# ...               ...                  ...                    ...
# 14584         Level 3  Basic Health Centre          HEALTH CENTRE
# 14643         Level 2           Dispensary             DISPENSARY
# 14667         Level 3  Basic Health Centre          HEALTH CENTRE
# 14674         Level 3  Basic Health Centre          HEALTH CENTRE
# 14733         Level 2           Dispensary             DISPENSARY
#
#                                      county  \
# 14     7c942357-44a8-49c9-9ca6-8247ad903b57
# 16     7c942357-44a8-49c9-9ca6-8247ad903b57
# 18     7c942357-44a8-49c9-9ca6-8247ad903b57
# 291    7c942357-44a8-49c9-9ca6-8247ad903b57
# 324    7c942357-44a8-49c9-9ca6-8247ad903b57
# ...                                     ...
# 14584  7c942357-44a8-49c9-9ca6-8247ad903b57
# 14643  7c942357-44a8-49c9-9ca6-8247ad903b57
# 14667  7c942357-44a8-49c9-9ca6-8247ad903b57
# 14674  7c942357-44a8-49c9-9ca6-8247ad903b57
# 14733  7c942357-44a8-49c9-9ca6-8247ad903b57
#
#                                constituency  \
# 14     ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 16     ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 18     8b79d994-5b2a-4686-9b89-85b5e6c709d6
# 291    e9d5c0e1-a0c3-4053-bd2a-052ff54a64e3
# 324    9fcb8e52-0034-4e8a-a610-c94c70cfa213
# ...                                     ...
# 14584  ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 14643  ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 14667  9fcb8e52-0034-4e8a-a610-c94c70cfa213
# 14674  655c6da0-4600-4ae0-9682-ad7e5e3b1c65
# 14733  655c6da0-4600-4ae0-9682-ad7e5e3b1c65
#
#                                        ward  ... infrastructure_categories  \
# 14     2e793f53-d493-485d-a6a1-efe5860c4c6c  ...                        []
# 16     6cd0e2df-f8da-4dc5-96a2-8517dde83168  ...                        []
# 18     2ccd3cc3-0f90-47d3-adb4-793fea3630d9  ...                        []
# 291    e8b07b8b-7499-4a1a-8809-67758b7f8d19  ...                        []
# 324    adff389b-2636-404b-a999-df218328df84  ...                        []
# ...                                     ...  ...                       ...
# 14584  2e793f53-d493-485d-a6a1-efe5860c4c6c  ...                        []
# 14643  6cd0e2df-f8da-4dc5-96a2-8517dde83168  ...                        []
# 14667  9eea54e2-7105-4f5f-bb9d-c15c02c06e88  ...                        []
# 14674  2a957f58-cd65-4b08-bbb5-dd0834aaaff8  ...                        []
# 14733  181f4986-ed8a-46d3-af8e-f6af8149f0a0  ...                        []
#
#                                         speciality_names  \
# 14     ['Pharm Tech', 'Casuals', 'KRCHN', 'General Cl...
# 16                                 ['KRCHN', 'Security']
# 18                ['General Clinical Officers(Diploma)']
# 291    ['Dental Technologists', 'Casuals', 'Cleaners'...
# 324    ['General Medical Officers', 'Medical Laborato...
# ...                                                  ...
# 14584                                                 []
# 14643                                                 []
# 14667                                                 []
# 14674                                                 []
# 14733                              ['Cleaners', 'KRCHN']
#
#                                    speciality_categories  is_public_visible  \
# 14     ['GENERAL SUPPORT STAFFS', 'CLINICAL OFFICERS'...               True
# 16            ['SUPPORT STAFF', 'NURSES AND SPECIALIST']               True
# 18                                 ['CLINICAL OFFICERS']               True
# 291    ['GENERAL SUPPORT STAFFS', 'MEDICAL LABORATORY...               True
# 324    ['MEDICAL LABORATORY', 'MEDICAL OFFICERS & SPE...               True
# ...                                                  ...                ...
# 14584                                                 []               True
# 14643                                                 []               True
# 14667                                                 []               True
# 14674                                                 []               True
# 14733         ['SUPPORT STAFF', 'NURSES AND SPECIALIST']               True
#
#                            created  closed is_published  \
# 14     2024-07-16T12:59:46.767058Z   False         True
# 16     2024-07-16T12:15:18.577285Z   False         True
# 18     2024-07-16T07:16:53.114238Z   False         True
# 291    2024-02-26T10:46:19.937796Z   False         True
# 324    2024-02-09T13:28:08.854025Z   False         True
# ...                            ...     ...          ...
# 14584         2009-10-31T00:00:00Z   False         True
# 14643         2009-10-31T00:00:00Z   False         True
# 14667         2009-10-31T00:00:00Z   False         True
# 14674         2009-10-31T00:00:00Z   False         True
# 14733         2009-10-31T00:00:00Z   False         True
#
#                                          id        lat      long
# 14     d2dd346b-20a5-4262-8390-13dabf4cd2f1  35.982215  0.470296
# 16     cfceebed-8a94-43aa-8421-a243f415b522  36.106182  0.371174
# 18     9701bcd2-008a-4137-a68a-9339370c5a6d  36.002876  0.068192
# 291    a76a2c4f-b92b-4614-8272-f2923fa13965  35.791240  0.619311
# 324    cc82f357-31c1-487f-83a2-6aeab52df07e  35.719931  0.492734
# ...                                     ...        ...       ...
# 14584  7a8d3b0d-7d24-4a23-8034-6607859f3632  35.891400  0.464780
# 14643  681d56dc-7c5f-40b9-83eb-98722120e471  36.254160  0.275930
# 14667  2c21d8e8-a26a-4c68-9a03-904018e072ec  35.716670  0.308830
# 14674  f7696e3f-63e7-44fc-b4ca-560c457a7a23  35.758700  1.216200
# 14733  27951a0a-50e3-4495-a9b7-6137a6d4cd24  35.992001  0.798041
#
# [305 rows x 47 columns]

# %%
# Optionally, you can save the merged DataFrame to a new CSV file
baringo_df.to_csv('data/baringo_df.csv', index=False)

# %% [markdown]
# ## Data Visualization
#
# - **df1**: Baringo Health facilities.
# - **df2**: Our data from KMHFR.

# %%
# Read the CSV files
df1 = pd.read_csv('data/BHF.csv') # data shared
# df2 = all_data
baringo_df = pd.read_csv('data/baringo_df.csv') #baringo df

# %%
# df2.shape[0]
baringo_df.columns
# Out:
# Index(['code', 'name', 'officialname', 'registration_number',
#        'keph_level_name', 'facility_type_name', 'facility_type_category',
#        'county', 'constituency', 'ward', 'owner_name', 'owner_type_name',
#        'regulatory_body_name', 'beds', 'cots', 'search', 'county_name',
#        'constituency_name', 'sub_county', 'sub_county_name', 'ward_name',
#        'keph_level', 'facility_type', 'owner_type', 'owner',
#        'operation_status', 'operation_status_name', 'admission_status_name',
#        'open_whole_day', 'open_public_holidays', 'open_weekends',
#        'open_late_night', 'services', 'categories', 'service_names',
#        'infrastructure', 'infrastructure_names', 'infrastructure_categories',
#        'speciality_names', 'speciality_categories', 'is_public_visible',
#        'created', 'closed', 'is_published', 'id', 'lat', 'long'],
#       dtype='object')

# %%
baringo_df
# Out:
#         code                                 name  \
# 0    31993.0                   Ngambo Health Care
# 1    31994.0                   Mbechot Dispensary
# 2    31986.0               Elicare Medical Clinic
# 3    31598.0                Lokaimoi Medicare LTD
# 4    31366.0  Equity Afia Kabarnet Medical Center
# ..       ...                                  ...
# 300  14867.0                Kimalel Health Centre
# 301  15386.0                 Ol-Arabel Dispensary
# 302  15197.0                Mogorwa Health Centre
# 303  14979.0                 Kolowa Health Centre
# 304  15091.0       Loruk Dispensary (Tiaty East )
#
#                             officialname registration_number keph_level_name  \
# 0                     Ngambo Health Care                 NaN         Level 2
# 1                     Mbechot Dispensary                 NaN         Level 2
# 2                 Elicare Medical Clinic              020807         Level 2
# 3                  Lokaimoi Medicare LTD           COC/F/110         Level 2
# 4    Equity Afia Kabarnet Medical Center              020541         Level 3
# ..                                   ...                 ...             ...
# 300                Kimalel Health Centre                 NaN         Level 3
# 301                 Ol-Arabel Dispensary                 NaN         Level 2
# 302                Mogorwa Health Centre                 NaN         Level 3
# 303                 Kolowa Health Centre                 NaN         Level 3
# 304        Loruk Dispensary (Tiaty East)                 NaN         Level 2
#
#       facility_type_name facility_type_category  \
# 0         Medical Clinic         MEDICAL CLINIC
# 1             Dispensary             DISPENSARY
# 2         Medical Clinic         MEDICAL CLINIC
# 3         Medical Center         MEDICAL CENTER
# 4         Medical Center         MEDICAL CENTER
# ..                   ...                    ...
# 300  Basic Health Centre          HEALTH CENTRE
# 301           Dispensary             DISPENSARY
# 302  Basic Health Centre          HEALTH CENTRE
# 303  Basic Health Centre          HEALTH CENTRE
# 304           Dispensary             DISPENSARY
#
#                                    county  \
# 0    7c942357-44a8-49c9-9ca6-8247ad903b57
# 1    7c942357-44a8-49c9-9ca6-8247ad903b57
# 2    7c942357-44a8-49c9-9ca6-8247ad903b57
# 3    7c942357-44a8-49c9-9ca6-8247ad903b57
# 4    7c942357-44a8-49c9-9ca6-8247ad903b57
# ..                                    ...
# 300  7c942357-44a8-49c9-9ca6-8247ad903b57
# 301  7c942357-44a8-49c9-9ca6-8247ad903b57
# 302  7c942357-44a8-49c9-9ca6-8247ad903b57
# 303  7c942357-44a8-49c9-9ca6-8247ad903b57
# 304  7c942357-44a8-49c9-9ca6-8247ad903b57
#
#                              constituency  \
# 0    ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 1    ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 2    8b79d994-5b2a-4686-9b89-85b5e6c709d6
# 3    e9d5c0e1-a0c3-4053-bd2a-052ff54a64e3
# 4    9fcb8e52-0034-4e8a-a610-c94c70cfa213
# ..                                    ...
# 300  ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 301  ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 302  9fcb8e52-0034-4e8a-a610-c94c70cfa213
# 303  655c6da0-4600-4ae0-9682-ad7e5e3b1c65
# 304  655c6da0-4600-4ae0-9682-ad7e5e3b1c65
#
#                                      ward  ... infrastructure_categories  \
# 0    2e793f53-d493-485d-a6a1-efe5860c4c6c  ...                        []
# 1    6cd0e2df-f8da-4dc5-96a2-8517dde83168  ...                        []
# 2    2ccd3cc3-0f90-47d3-adb4-793fea3630d9  ...                        []
# 3    e8b07b8b-7499-4a1a-8809-67758b7f8d19  ...                        []
# 4    adff389b-2636-404b-a999-df218328df84  ...                        []
# ..                                    ...  ...                       ...
# 300  2e793f53-d493-485d-a6a1-efe5860c4c6c  ...                        []
# 301  6cd0e2df-f8da-4dc5-96a2-8517dde83168  ...                        []
# 302  9eea54e2-7105-4f5f-bb9d-c15c02c06e88  ...                        []
# 303  2a957f58-cd65-4b08-bbb5-dd0834aaaff8  ...                        []
# 304  181f4986-ed8a-46d3-af8e-f6af8149f0a0  ...                        []
#
#                                       speciality_names  \
# 0    ['Pharm Tech', 'Casuals', 'KRCHN', 'General Cl...
# 1                                ['KRCHN', 'Security']
# 2               ['General Clinical Officers(Diploma)']
# 3    ['Dental Technologists', 'Casuals', 'Cleaners'...
# 4    ['General Medical Officers', 'Medical Laborato...
# ..                                                 ...
# 300                                                 []
# 301                                                 []
# 302                                                 []
# 303                                                 []
# 304                              ['Cleaners', 'KRCHN']
#
#                                  speciality_categories  is_public_visible  \
# 0    ['GENERAL SUPPORT STAFFS', 'CLINICAL OFFICERS'...               True
# 1           ['SUPPORT STAFF', 'NURSES AND SPECIALIST']               True
# 2                                ['CLINICAL OFFICERS']               True
# 3    ['GENERAL SUPPORT STAFFS', 'MEDICAL LABORATORY...               True
# 4    ['MEDICAL LABORATORY', 'MEDICAL OFFICERS & SPE...               True
# ..                                                 ...                ...
# 300                                                 []               True
# 301                                                 []               True
# 302                                                 []               True
# 303                                                 []               True
# 304         ['SUPPORT STAFF', 'NURSES AND SPECIALIST']               True
#
#                          created  closed is_published  \
# 0    2024-07-16T12:59:46.767058Z   False         True
# 1    2024-07-16T12:15:18.577285Z   False         True
# 2    2024-07-16T07:16:53.114238Z   False         True
# 3    2024-02-26T10:46:19.937796Z   False         True
# 4    2024-02-09T13:28:08.854025Z   False         True
# ..                           ...     ...          ...
# 300         2009-10-31T00:00:00Z   False         True
# 301         2009-10-31T00:00:00Z   False         True
# 302         2009-10-31T00:00:00Z   False         True
# 303         2009-10-31T00:00:00Z   False         True
# 304         2009-10-31T00:00:00Z   False         True
#
#                                        id        lat      long
# 0    d2dd346b-20a5-4262-8390-13dabf4cd2f1  35.982215  0.470296
# 1    cfceebed-8a94-43aa-8421-a243f415b522  36.106182  0.371174
# 2    9701bcd2-008a-4137-a68a-9339370c5a6d  36.002876  0.068192
# 3    a76a2c4f-b92b-4614-8272-f2923fa13965  35.791240  0.619311
# 4    cc82f357-31c1-487f-83a2-6aeab52df07e  35.719931  0.492734
# ..                                    ...        ...       ...
# 300  7a8d3b0d-7d24-4a23-8034-6607859f3632  35.891400  0.464780
# 301  681d56dc-7c5f-40b9-83eb-98722120e471  36.254160  0.275930
# 302  2c21d8e8-a26a-4c68-9a03-904018e072ec  35.716670  0.308830
# 303  f7696e3f-63e7-44fc-b4ca-560c457a7a23  35.758700  1.216200
# 304  27951a0a-50e3-4495-a9b7-6137a6d4cd24  35.992001  0.798041
#
# [305 rows x 47 columns]

# %% [markdown]
# ### Convert to gdf

# %%
baringo_df.columns
# Out:
# Index(['code', 'name', 'officialname', 'registration_number',
#        'keph_level_name', 'facility_type_name', 'facility_type_category',
#        'county', 'constituency', 'ward', 'owner_name', 'owner_type_name',
#        'regulatory_body_name', 'beds', 'cots', 'search', 'county_name',
#        'constituency_name', 'sub_county', 'sub_county_name', 'ward_name',
#        'keph_level', 'facility_type', 'owner_type', 'owner',
#        'operation_status', 'operation_status_name', 'admission_status_name',
#        'open_whole_day', 'open_public_holidays', 'open_weekends',
#        'open_late_night', 'services', 'categories', 'service_names',
#        'infrastructure', 'infrastructure_names', 'infrastructure_categories',
#        'speciality_names', 'speciality_categories', 'is_public_visible',
#        'created', 'closed', 'is_published', 'id', 'lat', 'long'],
#       dtype='object')

# %%
# Create a GeoDataFrame by converting latitude and longitude to geometry points
geometry = [Point(xy) for xy in zip(baringo_df['lat'], baringo_df['long'])]
gdf = gpd.GeoDataFrame(baringo_df, geometry=geometry)

# Set the coordinate reference system (CRS) to WGS84 (EPSG:4326)
gdf.set_crs(epsg=4326, inplace=True)
# Out:
#         code                                 name  \
# 0    31993.0                   Ngambo Health Care
# 1    31994.0                   Mbechot Dispensary
# 2    31986.0               Elicare Medical Clinic
# 3    31598.0                Lokaimoi Medicare LTD
# 4    31366.0  Equity Afia Kabarnet Medical Center
# ..       ...                                  ...
# 300  14867.0                Kimalel Health Centre
# 301  15386.0                 Ol-Arabel Dispensary
# 302  15197.0                Mogorwa Health Centre
# 303  14979.0                 Kolowa Health Centre
# 304  15091.0       Loruk Dispensary (Tiaty East )
#
#                             officialname registration_number keph_level_name  \
# 0                     Ngambo Health Care                 NaN         Level 2
# 1                     Mbechot Dispensary                 NaN         Level 2
# 2                 Elicare Medical Clinic              020807         Level 2
# 3                  Lokaimoi Medicare LTD           COC/F/110         Level 2
# 4    Equity Afia Kabarnet Medical Center              020541         Level 3
# ..                                   ...                 ...             ...
# 300                Kimalel Health Centre                 NaN         Level 3
# 301                 Ol-Arabel Dispensary                 NaN         Level 2
# 302                Mogorwa Health Centre                 NaN         Level 3
# 303                 Kolowa Health Centre                 NaN         Level 3
# 304        Loruk Dispensary (Tiaty East)                 NaN         Level 2
#
#       facility_type_name facility_type_category  \
# 0         Medical Clinic         MEDICAL CLINIC
# 1             Dispensary             DISPENSARY
# 2         Medical Clinic         MEDICAL CLINIC
# 3         Medical Center         MEDICAL CENTER
# 4         Medical Center         MEDICAL CENTER
# ..                   ...                    ...
# 300  Basic Health Centre          HEALTH CENTRE
# 301           Dispensary             DISPENSARY
# 302  Basic Health Centre          HEALTH CENTRE
# 303  Basic Health Centre          HEALTH CENTRE
# 304           Dispensary             DISPENSARY
#
#                                    county  \
# 0    7c942357-44a8-49c9-9ca6-8247ad903b57
# 1    7c942357-44a8-49c9-9ca6-8247ad903b57
# 2    7c942357-44a8-49c9-9ca6-8247ad903b57
# 3    7c942357-44a8-49c9-9ca6-8247ad903b57
# 4    7c942357-44a8-49c9-9ca6-8247ad903b57
# ..                                    ...
# 300  7c942357-44a8-49c9-9ca6-8247ad903b57
# 301  7c942357-44a8-49c9-9ca6-8247ad903b57
# 302  7c942357-44a8-49c9-9ca6-8247ad903b57
# 303  7c942357-44a8-49c9-9ca6-8247ad903b57
# 304  7c942357-44a8-49c9-9ca6-8247ad903b57
#
#                              constituency  \
# 0    ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 1    ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 2    8b79d994-5b2a-4686-9b89-85b5e6c709d6
# 3    e9d5c0e1-a0c3-4053-bd2a-052ff54a64e3
# 4    9fcb8e52-0034-4e8a-a610-c94c70cfa213
# ..                                    ...
# 300  ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 301  ca41dc5d-5673-4344-96b8-b4fde34b93bc
# 302  9fcb8e52-0034-4e8a-a610-c94c70cfa213
# 303  655c6da0-4600-4ae0-9682-ad7e5e3b1c65
# 304  655c6da0-4600-4ae0-9682-ad7e5e3b1c65
#
#                                      ward  ...  \
# 0    2e793f53-d493-485d-a6a1-efe5860c4c6c  ...
# 1    6cd0e2df-f8da-4dc5-96a2-8517dde83168  ...
# 2    2ccd3cc3-0f90-47d3-adb4-793fea3630d9  ...
# 3    e8b07b8b-7499-4a1a-8809-67758b7f8d19  ...
# 4    adff389b-2636-404b-a999-df218328df84  ...
# ..                                    ...  ...
# 300  2e793f53-d493-485d-a6a1-efe5860c4c6c  ...
# 301  6cd0e2df-f8da-4dc5-96a2-8517dde83168  ...
# 302  9eea54e2-7105-4f5f-bb9d-c15c02c06e88  ...
# 303  2a957f58-cd65-4b08-bbb5-dd0834aaaff8  ...
# 304  181f4986-ed8a-46d3-af8e-f6af8149f0a0  ...
#
#                                       speciality_names  \
# 0    ['Pharm Tech', 'Casuals', 'KRCHN', 'General Cl...
# 1                                ['KRCHN', 'Security']
# 2               ['General Clinical Officers(Diploma)']
# 3    ['Dental Technologists', 'Casuals', 'Cleaners'...
# 4    ['General Medical Officers', 'Medical Laborato...
# ..                                                 ...
# 300                                                 []
# 301                                                 []
# 302                                                 []
# 303                                                 []
# 304                              ['Cleaners', 'KRCHN']
#
#                                  speciality_categories is_public_visible  \
# 0    ['GENERAL SUPPORT STAFFS', 'CLINICAL OFFICERS'...              True
# 1           ['SUPPORT STAFF', 'NURSES AND SPECIALIST']              True
# 2                                ['CLINICAL OFFICERS']              True
# 3    ['GENERAL SUPPORT STAFFS', 'MEDICAL LABORATORY...              True
# 4    ['MEDICAL LABORATORY', 'MEDICAL OFFICERS & SPE...              True
# ..                                                 ...               ...
# 300                                                 []              True
# 301                                                 []              True
# 302                                                 []              True
# 303                                                 []              True
# 304         ['SUPPORT STAFF', 'NURSES AND SPECIALIST']              True
#
#                          created  closed  is_published  \
# 0    2024-07-16T12:59:46.767058Z   False          True
# 1    2024-07-16T12:15:18.577285Z   False          True
# 2    2024-07-16T07:16:53.114238Z   False          True
# 3    2024-02-26T10:46:19.937796Z   False          True
# 4    2024-02-09T13:28:08.854025Z   False          True
# ..                           ...     ...           ...
# 300         2009-10-31T00:00:00Z   False          True
# 301         2009-10-31T00:00:00Z   False          True
# 302         2009-10-31T00:00:00Z   False          True
# 303         2009-10-31T00:00:00Z   False          True
# 304         2009-10-31T00:00:00Z   False          True
#
#                                        id        lat      long  \
# 0    d2dd346b-20a5-4262-8390-13dabf4cd2f1  35.982215  0.470296
# 1    cfceebed-8a94-43aa-8421-a243f415b522  36.106182  0.371174
# 2    9701bcd2-008a-4137-a68a-9339370c5a6d  36.002876  0.068192
# 3    a76a2c4f-b92b-4614-8272-f2923fa13965  35.791240  0.619311
# 4    cc82f357-31c1-487f-83a2-6aeab52df07e  35.719931  0.492734
# ..                                    ...        ...       ...
# 300  7a8d3b0d-7d24-4a23-8034-6607859f3632  35.891400  0.464780
# 301  681d56dc-7c5f-40b9-83eb-98722120e471  36.254160  0.275930
# 302  2c21d8e8-a26a-4c68-9a03-904018e072ec  35.716670  0.308830
# 303  f7696e3f-63e7-44fc-b4ca-560c457a7a23  35.758700  1.216200
# 304  27951a0a-50e3-4495-a9b7-6137a6d4cd24  35.992001  0.798041
#
#                      geometry
# 0    POINT (35.98221 0.47030)
# 1    POINT (36.10618 0.37117)
# 2    POINT (36.00288 0.06819)
# 3    POINT (35.79124 0.61931)
# 4    POINT (35.71993 0.49273)
# ..                        ...
# 300  POINT (35.89140 0.46478)
# 301  POINT (36.25416 0.27593)
# 302  POINT (35.71667 0.30883)
# 303  POINT (35.75870 1.21620)
# 304  POINT (35.99200 0.79804)
#
# [305 rows x 48 columns]

# %%
gdf.columns
# Out:
# Index(['code', 'name', 'officialname', 'registration_number',
#        'keph_level_name', 'facility_type_name', 'facility_type_category',
#        'county', 'constituency', 'ward', 'owner_name', 'owner_type_name',
#        'regulatory_body_name', 'beds', 'cots', 'search', 'county_name',
#        'constituency_name', 'sub_county', 'sub_county_name', 'ward_name',
#        'keph_level', 'facility_type', 'owner_type', 'owner',
#        'operation_status', 'operation_status_name', 'admission_status_name',
#        'open_whole_day', 'open_public_holidays', 'open_weekends',
#        'open_late_night', 'services', 'categories', 'service_names',
#        'infrastructure', 'infrastructure_names', 'infrastructure_categories',
#        'speciality_names', 'speciality_categories', 'is_public_visible',
#        'created', 'closed', 'is_published', 'id', 'lat', 'long', 'geometry'],
#       dtype='object')

# %%
# Print the number of rows in the DataFrame
print(f"Number of rows: {gdf.shape[0]}")
gdf.explore(
    column='facility_type_category',  # Column to color by
    cmap='viridis',            # Colormap
    legend=True,               # Show legend
    legend_kwds={
        'loc': 'topright',     # Position of the legend
        'title': 'Keph facility_type_category', # Title of the legend
    },
    tooltip='keph_level_name', # Tooltip information
    style_kwds=dict(radius=4, fillOpacity=0.7)  # Style options
)
# Out:
# Number of rows: 305
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac2809e4d3781b454431b0cc7bce6e73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend facility_type_category&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;facility_type_category&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#440154&#x27;&gt;&lt;/span&gt;DISPENSARY&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#414487&#x27;&gt;&lt;/span&gt;HEALTH CENTRE&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2a788e&#x27;&gt;&lt;/span&gt;HOSPITALS&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#22a884&#x27;&gt;&lt;/span&gt;MEDICAL CENTER&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7ad151&#x27;&gt;&lt;/span&gt;MEDICAL CLINIC&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fde725&#x27;&gt;&lt;/span&gt;STAND ALONE&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac2809e4d3781b454431b0cc7bce6e73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac2809e4d3781b454431b0cc7bce6e73 = L.map(
#                 &quot;map_ac2809e4d3781b454431b0cc7bce6e73&quot;,
#                 {
#                     center: [0.704075, 35.992194999999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ac2809e4d3781b454431b0cc7bce6e73);
#
#
#
#
#
#             var tile_layer_faed34d708faa8704b10fb1416f99f5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_faed34d708faa8704b10fb1416f99f5a.addTo(map_ac2809e4d3781b454431b0cc7bce6e73);
#
#
#             map_ac2809e4d3781b454431b0cc7bce6e73.fitBounds(
#                 [[-0.04644, 35.56755], [1.45459, 36.41684]],
#                 {}
#             );
#
#
#         function geo_json_83ba4797c3273bd358dd157cc0940ed8_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;47&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: cas

# %%
gdf.columns
# Out:
# Index(['code', 'name', 'officialname', 'registration_number',
#        'keph_level_name', 'facility_type_name', 'facility_type_category',
#        'county', 'constituency', 'ward', 'owner_name', 'owner_type_name',
#        'regulatory_body_name', 'beds', 'cots', 'search', 'county_name',
#        'constituency_name', 'sub_county', 'sub_county_name', 'ward_name',
#        'keph_level', 'facility_type', 'owner_type', 'owner',
#        'operation_status', 'operation_status_name', 'admission_status_name',
#        'open_whole_day', 'open_public_holidays', 'open_weekends',
#        'open_late_night', 'services', 'categories', 'service_names',
#        'infrastructure', 'infrastructure_names', 'infrastructure_categories',
#        'speciality_names', 'speciality_categories', 'is_public_visible',
#        'created', 'closed', 'is_published', 'id', 'lat', 'long', 'geometry'],
#       dtype='object')

# %% [markdown]
# ###  drop unneccesary columns

# %%
# Drop specified columns from the GeoDataFrame
#gdf = gdf.drop(columns=['county', 'constituency', 'ward'])
gdf
# Out:
#         code                                 name  \
# 0    31993.0                   Ngambo Health Care
# 1    31994.0                   Mbechot Dispensary
# 2    31986.0               Elicare Medical Clinic
# 3    31598.0                Lokaimoi Medicare LTD
# 4    31366.0  Equity Afia Kabarnet Medical Center
# ..       ...                                  ...
# 300  14867.0                Kimalel Health Centre
# 301  15386.0                 Ol-Arabel Dispensary
# 302  15197.0                Mogorwa Health Centre
# 303  14979.0                 Kolowa Health Centre
# 304  15091.0       Loruk Dispensary (Tiaty East )
#
#                             officialname registration_number keph_level_name  \
# 0                     Ngambo Health Care                 NaN         Level 2
# 1                     Mbechot Dispensary                 NaN         Level 2
# 2                 Elicare Medical Clinic              020807         Level 2
# 3                  Lokaimoi Medicare LTD           COC/F/110         Level 2
# 4    Equity Afia Kabarnet Medical Center              020541         Level 3
# ..                                   ...                 ...             ...
# 300                Kimalel Health Centre                 NaN         Level 3
# 301                 Ol-Arabel Dispensary                 NaN         Level 2
# 302                Mogorwa Health Centre                 NaN         Level 3
# 303                 Kolowa Health Centre                 NaN         Level 3
# 304        Loruk Dispensary (Tiaty East)                 NaN         Level 2
#
#       facility_type_name facility_type_category  \
# 0         Medical Clinic         MEDICAL CLINIC
# 1             Dispensary             DISPENSARY
# 2         Medical Clinic         MEDICAL CLINIC
# 3         Medical Center         MEDICAL CENTER
# 4         Medical Center         MEDICAL CENTER
# ..                   ...                    ...
# 300  Basic Health Centre          HEALTH CENTRE
# 301           Dispensary             DISPENSARY
# 302  Basic Health Centre          HEALTH CENTRE
# 303  Basic Health Centre          HEALTH CENTRE
# 304           Dispensary             DISPENSARY
#
#                               owner_name     owner_type_name  \
# 0           Private Practice- Pharmacist    Private Practice
# 1                     Ministry of Health  Ministry of Health
# 2    Private Practice - Clinical Officer    Private Practice
# 3     Private Practice - Private Company    Private Practice
# 4     Private Practice - Private Company    Private Practice
# ..                                   ...                 ...
# 300                   Ministry of Health  Ministry of Health
# 301                   Ministry of Health  Ministry of Health
# 302                   Ministry of Health  Ministry of Health
# 303                   Ministry of Health  Ministry of Health
# 304                   Ministry of Health  Ministry of Health
#
#           regulatory_body_name  ...  \
# 0                          NaN  ...
# 1           Ministry of Health  ...
# 2    Clinical Officers Council  ...
# 3    Clinical Officers Council  ...
# 4     Pharmacy & Poisons Board  ...
# ..                         ...  ...
# 300         Ministry of Health  ...
# 301         Ministry of Health  ...
# 302         Ministry of Health  ...
# 303         Ministry of Health  ...
# 304         Ministry of Health  ...
#
#                                       speciality_names  \
# 0    ['Pharm Tech', 'Casuals', 'KRCHN', 'General Cl...
# 1                                ['KRCHN', 'Security']
# 2               ['General Clinical Officers(Diploma)']
# 3    ['Dental Technologists', 'Casuals', 'Cleaners'...
# 4    ['General Medical Officers', 'Medical Laborato...
# ..                                                 ...
# 300                                                 []
# 301                                                 []
# 302                                                 []
# 303                                                 []
# 304                              ['Cleaners', 'KRCHN']
#
#                                  speciality_categories  is_public_visible  \
# 0    ['GENERAL SUPPORT STAFFS', 'CLINICAL OFFICERS'...               True
# 1           ['SUPPORT STAFF', 'NURSES AND SPECIALIST']               True
# 2                                ['CLINICAL OFFICERS']               True
# 3    ['GENERAL SUPPORT STAFFS', 'MEDICAL LABORATORY...               True
# 4    ['MEDICAL LABORATORY', 'MEDICAL OFFICERS & SPE...               True
# ..                                                 ...                ...
# 300                                                 []               True
# 301                                                 []               True
# 302                                                 []               True
# 303                                                 []               True
# 304         ['SUPPORT STAFF', 'NURSES AND SPECIALIST']               True
#
#                          created closed is_published  \
# 0    2024-07-16T12:59:46.767058Z  False         True
# 1    2024-07-16T12:15:18.577285Z  False         True
# 2    2024-07-16T07:16:53.114238Z  False         True
# 3    2024-02-26T10:46:19.937796Z  False         True
# 4    2024-02-09T13:28:08.854025Z  False         True
# ..                           ...    ...          ...
# 300         2009-10-31T00:00:00Z  False         True
# 301         2009-10-31T00:00:00Z  False         True
# 302         2009-10-31T00:00:00Z  False         True
# 303         2009-10-31T00:00:00Z  False         True
# 304         2009-10-31T00:00:00Z  False         True
#
#                                        id        lat      long  \
# 0    d2dd346b-20a5-4262-8390-13dabf4cd2f1  35.982215  0.470296
# 1    cfceebed-8a94-43aa-8421-a243f415b522  36.106182  0.371174
# 2    9701bcd2-008a-4137-a68a-9339370c5a6d  36.002876  0.068192
# 3    a76a2c4f-b92b-4614-8272-f2923fa13965  35.791240  0.619311
# 4    cc82f357-31c1-487f-83a2-6aeab52df07e  35.719931  0.492734
# ..                                    ...        ...       ...
# 300  7a8d3b0d-7d24-4a23-8034-6607859f3632  35.891400  0.464780
# 301  681d56dc-7c5f-40b9-83eb-98722120e471  36.254160  0.275930
# 302  2c21d8e8-a26a-4c68-9a03-904018e072ec  35.716670  0.308830
# 303  f7696e3f-63e7-44fc-b4ca-560c457a7a23  35.758700  1.216200
# 304  27951a0a-50e3-4495-a9b7-6137a6d4cd24  35.992001  0.798041
#
#                      geometry
# 0    POINT (35.98221 0.47030)
# 1    POINT (36.10618 0.37117)
# 2    POINT (36.00288 0.06819)
# 3    POINT (35.79124 0.61931)
# 4    POINT (35.71993 0.49273)
# ..                        ...
# 300  POINT (35.89140 0.46478)
# 301  POINT (36.25416 0.27593)
# 302  POINT (35.71667 0.30883)
# 303  POINT (35.75870 1.21620)
# 304  POINT (35.99200 0.79804)
#
# [305 rows x 45 columns]

# %%
# Define the list of columns you want to display in the tooltip
tooltip_columns = ['name',  'beds', 'cots', 'search', 
       'operation_status', 'operation_status_name', 'admission_status_name',
       'open_whole_day', 'open_public_holidays', 'open_weekends',
       'open_late_night'] 

# Generate the interactive map with detailed tooltip
m = gdf.explore(
    column='facility_type_category',  # Column to color by
    cmap='viridis',            # Colormap
    legend=True,               # Show legend
    tooltip=tooltip_columns,   # List of columns to show in the tooltip
    style_kwds=dict(radius=4, fillOpacity=0.7)  # Style options
)

# Save the map as an HTML file
m.save('interactive_map.html')
